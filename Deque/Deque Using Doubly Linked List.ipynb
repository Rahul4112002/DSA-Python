# %% [markdown]
# # Deque Using Doubly Linked List

# %%
class Node:
    def __init__(self,prev=None,item=None,next=None):
        self.prev = prev
        self.item = item
        self.next = next
class Deque:
    def __init__(self):
        self.front = None
        self.rear = None
        self.item_count = 0
    def is_empty(self):
        return self.front == None
    def insert_front(self,data):
        n = Node(None,data,self.front)
        if self.is_empty():
            self.rear = n
        else:
            self.front.prev = n
        self.front = n
        self.item_count += 1
    def insert_rear(self,data):
        n = Node(self.rear,data,None)
        if self.is_empty():
            self.front = n           
        else:
            self.rear.next = n
        self.rear = n   
        self.item_count += 1
    def delete_front(self):
        if self.is_empty():
            raise IndexError('Deque is Empty')
        elif self.front == self.rear:
            self.front = None
            self.rear = None
        else:
            self.front = self.front.next
            self.front.prev = None
        self.item_count -= 1
    def delete_rear(self):
        if self.is_empty():
            raise IndexError('Deque is Empty')
        elif self.front == self.rear:
            self.front = None
            self.rear = None
        else:
            self.rear = self.rear.prev
            self.rear.next = None
        self.item_count -= 1
    def get_front(self):
        if self.is_empty():
            raise IndexError('Deque is Empty')
        else:
            return self.fornt.item
    def get_rear(self):
        if self.is_empty():
            raise IndexError('Deque is Empty')
        else:
            return self.rear.item 
    def size(self):
        return len(self.item_count)
    
d = Deque()
d.insert_front(10)
d.insert_front(20)
d.insert_rear(30)
d.insert_rear(40)
print(d.get_front(),d.get_rear())
d.delete_front()
d.delete_rear()
print(d.get_front(),d.get_rear())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [2], line 67
#      65 d.insert_rear(30)
#      66 d.insert_rear(40)
# ---> 67 print(d.get_front(),d.get_rear())
#      68 d.delete_front()
#      69 d.delete_rear()
#
# Cell In [2], line 53, in Deque.get_front(self)
#      51     raise IndexError('Deque is Empty')
#      52 else:
# ---> 53     return self.fornt.item
#
# AttributeError: 'Deque' object has no attribute 'fornt'
